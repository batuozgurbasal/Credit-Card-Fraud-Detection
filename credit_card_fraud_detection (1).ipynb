# %%
import pandas as pd
df = pd.read_csv("/content/creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df['Class']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# **It seems like we don't have any missing values, that's great!**
#
# ---

# %%
df.dropna()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool

# %% [markdown]
# **Great! We do not have any duplicated values. Now, let's dive deep into the data a little bit more to see if we can find out something useful.**
#
# ---

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# import matplotlib.pyplot as plt

# fig, ax = plt.subplots(figsize=(8,4))
# ax.scatter(df['V1'], df['Class'])
# ax.set_xlabel('V1 Column')
# ax.set_ylabel('Class columns')
# plt.show()

# %%
# import numpy as np
# df2 = df[['Amount','Class']]
# list = []
# for i in range(1,29):
#   list.append("V"+str(i))
# df = pd.DataFrame(np.random.rand(284807, 28), columns=list)
# df.plot.box(figsize=(20, 8));

# %% [markdown]
# **Let's plot the histogram of all the "V" Features**
#
# ---

# %%
features = []
for i in range(1,29):
  features.append("V"+str(i))
df.hist(column=features, figsize=(50, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f400f5d2f50>,
# ...
#       dtype=object)

# %% [markdown]
# **What is the relationship between the amount spent and fraud?**
#
# ---

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df['Amount'], df['Class'])
ax.set_xlabel('Amount')
ax.set_ylabel('Class')
plt.show()

# %% [markdown]
# **How many fraud and non-fraud activities we have?**
#
# ---

# %%
df['Class'].value_counts().plot(kind = 'bar',figsize = (5,5))

# %% [markdown]
# **Apparently, we have unbalanced data! Let's see the connection between transactions and time.**
#
# ---

# %%
import plotly.figure_factory as ff
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
class_0 = df.loc[df['Class'] == 0]["Time"]
class_1 = df.loc[df['Class'] == 1]["Time"]

hist_data = [class_0, class_1]
group_labels = ['Not Fraud', 'Fraud']

fig = ff.create_distplot(hist_data, group_labels, show_hist=False, show_rug=False)
fig['layout'].update(title='Credit Card Transactions Time Density Plot', xaxis=dict(title='Time [s]'))
iplot(fig, filename='dist_only')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

plt.figure(figsize = (14,14))
plt.title('Transactions features correlation matrix')
corr = df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,cmap="Greens")
plt.show()

# %% [markdown]
# **Feature "V7" and "V20" has a significant relationship with feature "Amount".**
#
# ---

# %%
fig, ax = plt.subplots(figsize=(16,3))
ax.scatter(df['V7'], df['Amount'])
ax.set_xlabel('V7 Column')
ax.set_ylabel('Amount of transaction')
plt.show()

fig, ax = plt.subplots(figsize=(16,3))
ax.scatter(df['V20'], df['Amount'])
ax.set_xlabel('V20 Column')
ax.set_ylabel('Amount of transaction')
plt.show()

# %% [markdown]
# **Feature "V4" and "V11" has a significant relationship with feature
# "Class"(target feature).**
#
# ---

# %%
fig, ax = plt.subplots(figsize=(15,3))
ax.scatter(df['V4'], df['Class'])
ax.set_xlabel('V4 Column')
ax.set_ylabel('Fraud or Not')
plt.show()

fig, ax = plt.subplots(figsize=(15,3))
ax.scatter(df['V11'], df['Class'])
ax.set_xlabel('V11 Column')
ax.set_ylabel('Fraud or Not')
plt.show()

# %% [markdown]
# **Let's see the feature importance using XGBoost**

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from matplotlib import pyplot

y = df['Class']
df.drop('Class', axis=1, inplace=True)
x = df
# fit model no training data
model = XGBClassifier()
model.fit(x, y)
# feature importance
print(model.feature_importances_)
# plot
pyplot.bar(range(len(model.feature_importances_)), model.feature_importances_)
pyplot.show()
# Out:
# [0.03780393 0.01312177 0.01883874 0.01882652 0.02463404 0.01788771
#  0.01956656 0.034152   0.01975285 0.02792782 0.0555035  0.01836529
#  0.03408745 0.02304275 0.11691193 0.01709109 0.01856367 0.26877394
#  0.01642537 0.01757907 0.02282348 0.01415598 0.01480647 0.00959567
#  0.01497851 0.         0.02913272 0.03324063 0.02598226 0.0164283 ]

# %% [markdown]
# **Model Training with XGBoost**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score, roc_curve, cohen_kappa_score, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30)

# %%
y_pred = model.predict(x_test)
('Accuracy Score:', metrics.accuracy_score(y_test,y_pred))
# Out:
# ('Accuracy Score:', 0.9996839998595555)

# %%
target_names = ["Normal", "Fraud"]
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     85301
#        Fraud       0.97      0.84      0.90       142
#
#     accuracy                           1.00     85443
#    macro avg       0.98      0.92      0.95     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal','Fraud'])
disp.plot()
plt.show()
